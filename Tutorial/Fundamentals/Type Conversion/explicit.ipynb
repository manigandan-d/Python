# %%
print(int("123") + 7)
# Out:
# 130

# %%
print(int("0101", 2))
# Out:
# 5

# %%
print(int("177", 8))
# Out:
# 127

# %%
print(int("1be", 16))
# Out:
# 446

# %%
print(float(15) + 2)
# Out:
# 17.0

# %%
print(float("3.14"))
# Out:
# 3.14

# %%
print("python" + str(123))
# Out:
# python123
