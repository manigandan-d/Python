# %%
data = [2, 4, 6, 8, 10]

# %%
for i in data:
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
it = iter(data)

for i in data:
    print(it.__next__())
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
it = iter(data)

for i in data: 
    print(next(it))
# Out:
# 2
# 4
# 6
# 8
# 10
