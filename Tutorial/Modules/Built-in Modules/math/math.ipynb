# %% [markdown]
# math module

# %%
import math

# %% [markdown]
# euler's number

# %%
math.e
# Out:
# 2.718281828459045

# %% [markdown]
# pi

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# tau

# %%
math.tau
# Out:
# 6.283185307179586

# %% [markdown]
# infinity

# %%
math.inf
# Out:
# inf

# %% [markdown]
# nan

# %%
math.nan
# Out:
# nan

# %% [markdown]
# sqrt()

# %%
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# floor()

# %%
num=5.8
print(math.floor(num))

num=5.3
print(math.floor(num))

num=5.5
print(math.floor(num))
# Out:
# 5
# 5
# 5

# %% [markdown]
# ceil()

# %%
num=5.8
print(math.ceil(num))

num=5.3
print(math.ceil(num))

num=5.5
print(math.ceil(num))
# Out:
# 6
# 6
# 6
